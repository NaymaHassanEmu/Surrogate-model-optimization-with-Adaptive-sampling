# %%
from scipy.optimize import minimize
import joblib
import numpy as np
# %run 2.Hicks_Henne_NEW_Final.ipynb
# %run 3.Xfoil_runner_extract_value.ipynb

# %%
def get_new_sobol_samples(limit, num_samples, seed=None):
    l00, l01 = limit[0][0], limit[0][1]
    l10, l11 = limit[1][0], limit[1][1]
    l20, l21 = limit[2][0], limit[2][1]
    l30, l31 = limit[3][0], limit[3][1]
    l40, l41 = limit[4][0], limit[4][1]
    l50, l51 = limit[5][0], limit[5][1] 
    l60, l61 = limit[6][0], limit[6][1]
    l70, l71 = limit[7][0], limit[7][1]
    
    bounds = {"x1": [l00, l01], "x2": [l10, l11], "x3": [l20, l21], "x4": [l30, l31], 
              "x5": [l40, l41], "x6": [l50, l51], "x7": [l60, l61], "x8": [l70, l71]}
    sampler = Sobol(len(bounds), seed=seed)
    samples = sampler.random(num_samples)
    
    l_bounds = [bound[0] for bound in bounds.values()]
    u_bounds = [bound[1] for bound in bounds.values()]
    samples = qmc.scale(samples, l_bounds, u_bounds)
    design_parameter = pd.DataFrame(samples, columns=list(bounds.keys())).round(4)
    a = design_parameter.apply(np.array, axis=1)
    return a

# %%
new_dataset = pd.read_excel('new_dataset.xlsx')
new_dataset.drop(columns=['Unnamed: 0'], inplace=True)
new_dataset
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# 0    0.008400  0.010400 -0.003300 -0.003300 -0.008600  0.001500 -0.001900
# 1   -0.004500 -0.003500  0.005700  0.006200  0.010600 -0.006000  0.010100
# 2   -0.009300  0.003800 -0.008300 -0.011300  0.003000 -0.002800 -0.009300
# 3    0.001900 -0.009300  0.006700  0.002500 -0.001200  0.007700  0.002600
# 4    0.004500  0.001700  0.002600  0.005000 -0.003900  0.003400 -0.008700
# ..        ...       ...       ...       ...       ...       ...       ...
# 156 -0.000500  0.012100  0.012500  0.011800  0.012200  0.006700  0.009000
# 157 -0.001700  0.012000  0.011000  0.012200  0.011300  0.007900  0.007700
# 158  0.012000  0.011585 -0.006974 -0.011997  0.006540 -0.011989  0.011206
# 159  0.012000  0.007768 -0.002273 -0.012000  0.011855 -0.011839  0.006805
# 160  0.011626  0.011420 -0.006901 -0.011876  0.007370 -0.011933  0.009516
#
#            x8      CL       CD
# 0   -0.002700  0.5294  0.00733
# 1    0.003700  0.6747  0.00947
# 2    0.008500  0.4693  0.00959
# 3   -0.009200  0.5034  0.00928
# 4    0.010500  0.6249  0.00916
# ..        ...     ...      ...
# 156  0.004500  0.8246  0.00967
# 157  0.006000  0.8119  0.00981
# 158  0.011068  0.6373  0.00791
# 159  0.009451  0.6274  0.00794
# 160  0.011580  0.6348  0.00792
#
# [161 rows x 10 columns]

# %%
length = len(new_dataset)
length
# Out:
# 161

# %%
X = new_dataset[['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8'] ]
X = X.apply(np.array, axis = 1)
new_sample_param = X[[length-3,length-2,length-1]]
new_sample_param
# Out:
# 158    [0.01199999999994268, 0.01158496871911083, -0....
# 159    [0.012, 0.007768379557214065, -0.0022733334399...
# 160    [0.01162590223762493, 0.01141979429946418, -0....
# dtype: object

# %%
disp = 0.001
new_num_samples = 4
for i in [length-3,length-2,length-1]:
    limit= []
    a_new = X[i]
    for j in a_new:
        l= []
        l.append(j-disp)
        l.append(j+disp)
        limit.append(l)
    s_new = get_new_sobol_samples(limit, new_num_samples, seed=42)
    new_sample_param = np.append(new_sample_param,s_new)
new_sample_param
# Out:
# array([array([ 0.012     ,  0.01158497, -0.00697418, -0.01199743,  0.00654022,
#               -0.01198941,  0.01120577,  0.01106774])                         ,
#        array([ 0.012     ,  0.00776838, -0.00227333, -0.012     ,  0.01185502,
#               -0.01183948,  0.0068049 ,  0.00945073])                         ,
#        array([ 0.0116259 ,  0.01141979, -0.00690087, -0.01187617,  0.00736982,
#               -0.01193345,  0.00951577,  0.01158048])                         ,
#        array([ 0.0119,  0.0122, -0.0064, -0.0129,  0.0061, -0.0113,  0.0116,
#                0.0113])                                                     ,
#        array([ 0.0129,  0.0108, -0.0071, -0.011 ,  0.0074, -0.0121,  0.0102,
#                0.0108])                                                     ,
#        array([ 0.0122,  0.0117, -0.0065, -0.0121,  0.0068, -0.0127,  0.0121,
#                0.0105])                                                     ,
#        array([ 0.011 ,  0.0116, -0.0079, -0.0118,  0.0058, -0.0115,  0.0108,
#                0.012 ])                                                     ,
#        array([ 0.0119,  0.0084, -0.0017, -0.0129,  0.0115, -0.0112,  0.0072,
#                0.0097])                                                     ,
#        array([ 0.0129,  0.007 , -0.0024, -0.011 ,  0.0127, -0.0119,  0.0058,
#                0.0091])                                                     ,
#        array([ 0.0122,  0.0079, -0.0018, -0.0121,  0.0121, -0.0126,  0.0077,
#                0.0089])                                                     ,
#        array([ 0.011 ,  0.0077, -0.0032, -0.0118,  0.0111, -0.0114,  0.0064,
#                0.0104])                                                     ,
#        array([ 0.0115,  0.012 , -0.0063, -0.0128,  0.007 , -0.0113,  0.0099,
#                0.0118])                                                     ,
#        array([ 0.0125,  0.0107, -0.007 , -0.0109,  0.0083, -0.012 ,  0.0086,
#                0.0113])                                                     ,
#        array([ 0.0118,  0.0115, -0.0064, -0.012 ,  0.0076, -0.0127,  0.0104,
#                0.011 ])                                                     ,
#        array([ 0.0107,  0.0114, -0.0079, -0.0117,  0.0066, -0.0115,  0.0091,
#                0.0125])                                                     ],
#       dtype=object)

# %%
len(new_sample_param)
# Out:
# 15

# %%
def deformed_foil_generator(x, y, n, a, w, xM):
    for i in range(len(a)):
        y_mod = hicks_henne_overall(x, y, n, a, i, w, xM)
        df = pd.DataFrame({'x': x, 'y_modified': y_mod})
        path = "Deformed_foils\\Deformed_airfoil_" + str(i+160) + ".dat"
        
        df.to_csv(path, index=False, sep=' ')

# %%
if globals().get('__file__', '') == '':
    deformed_foil_generator(x, y, n, new_sample_param, w, xM)

# %%
new_sample_param = np.vstack(new_sample_param)
new_sample_param
# Out:
# array([[ 0.012     ,  0.01158497, -0.00697418, -0.01199743,  0.00654022,
#         -0.01198941,  0.01120577,  0.01106774],
#        [ 0.012     ,  0.00776838, -0.00227333, -0.012     ,  0.01185502,
#         -0.01183948,  0.0068049 ,  0.00945073],
#        [ 0.0116259 ,  0.01141979, -0.00690087, -0.01187617,  0.00736982,
#         -0.01193345,  0.00951577,  0.01158048],
#        [ 0.0119    ,  0.0122    , -0.0064    , -0.0129    ,  0.0061    ,
#         -0.0113    ,  0.0116    ,  0.0113    ],
#        [ 0.0129    ,  0.0108    , -0.0071    , -0.011     ,  0.0074    ,
#         -0.0121    ,  0.0102    ,  0.0108    ],
#        [ 0.0122    ,  0.0117    , -0.0065    , -0.0121    ,  0.0068    ,
#         -0.0127    ,  0.0121    ,  0.0105    ],
#        [ 0.011     ,  0.0116    , -0.0079    , -0.0118    ,  0.0058    ,
#         -0.0115    ,  0.0108    ,  0.012     ],
#        [ 0.0119    ,  0.0084    , -0.0017    , -0.0129    ,  0.0115    ,
#         -0.0112    ,  0.0072    ,  0.0097    ],
#        [ 0.0129    ,  0.007     , -0.0024    , -0.011     ,  0.0127    ,
#         -0.0119    ,  0.0058    ,  0.0091    ],
#        [ 0.0122    ,  0.0079    , -0.0018    , -0.0121    ,  0.0121    ,
#         -0.0126    ,  0.0077    ,  0.0089    ],
#        [ 0.011     ,  0.0077    , -0.0032    , -0.0118    ,  0.0111    ,
#         -0.0114    ,  0.0064    ,  0.0104    ],
#        [ 0.0115    ,  0.012     , -0.0063    , -0.0128    ,  0.007     ,
#         -0.0113    ,  0.0099    ,  0.0118    ],
#        [ 0.0125    ,  0.0107    , -0.007     , -0.0109    ,  0.0083    ,
#         -0.012     ,  0.0086    ,  0.0113    ],
#        [ 0.0118    ,  0.0115    , -0.0064    , -0.012     ,  0.0076    ,
#         -0.0127    ,  0.0104    ,  0.011     ],
#        [ 0.0107    ,  0.0114    , -0.0079    , -0.0117    ,  0.0066    ,
#         -0.0115    ,  0.0091    ,  0.0125    ]])

# %%
new_sample_param.shape
# Out:
# (15, 8)

# %%
len(new_sample_param)
# Out:
# 15

# %%
columns = ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8']
new_sample_param = pd.DataFrame(new_sample_param, columns=columns)
new_sample_param
# Out:
#           x1        x2        x3        x4        x5        x6        x7  \
# 0   0.012000  0.011585 -0.006974 -0.011997  0.006540 -0.011989  0.011206
# 1   0.012000  0.007768 -0.002273 -0.012000  0.011855 -0.011839  0.006805
# 2   0.011626  0.011420 -0.006901 -0.011876  0.007370 -0.011933  0.009516
# 3   0.011900  0.012200 -0.006400 -0.012900  0.006100 -0.011300  0.011600
# 4   0.012900  0.010800 -0.007100 -0.011000  0.007400 -0.012100  0.010200
# 5   0.012200  0.011700 -0.006500 -0.012100  0.006800 -0.012700  0.012100
# 6   0.011000  0.011600 -0.007900 -0.011800  0.005800 -0.011500  0.010800
# 7   0.011900  0.008400 -0.001700 -0.012900  0.011500 -0.011200  0.007200
# 8   0.012900  0.007000 -0.002400 -0.011000  0.012700 -0.011900  0.005800
# 9   0.012200  0.007900 -0.001800 -0.012100  0.012100 -0.012600  0.007700
# 10  0.011000  0.007700 -0.003200 -0.011800  0.011100 -0.011400  0.006400
# 11  0.011500  0.012000 -0.006300 -0.012800  0.007000 -0.011300  0.009900
# 12  0.012500  0.010700 -0.007000 -0.010900  0.008300 -0.012000  0.008600
# 13  0.011800  0.011500 -0.006400 -0.012000  0.007600 -0.012700  0.010400
# 14  0.010700  0.011400 -0.007900 -0.011700  0.006600 -0.011500  0.009100
#
#           x8
# 0   0.011068
# 1   0.009451
# 2   0.011580
# 3   0.011300
# 4   0.010800
# 5   0.010500
# 6   0.012000
# 7   0.009700
# 8   0.009100
# 9   0.008900
# 10  0.010400
# 11  0.011800
# 12  0.011300
# 13  0.011000
# 14  0.012500

# %%
new_sample_param.to_excel('new_sample_param.xlsx')

# %%
if globals().get('__file__', '') == '':
    # Save the current directory
    original_directory = os.getcwd()
    
    # Navigate to another folder
    os.chdir(original_directory + '\\Deformed_foils')

# %%
def new_deformed_foil_data_from_Xfoil(alpha, Re, n_iter, num_samples, file_name):
    #outputs
    CL = []
    CD = []
    for i in range(num_samples):
        airfoil_name = "Deformed_airfoil_"+str(i+160)
        cl_i, cd_i = Xfoil_runner(alpha, Re, n_iter, airfoil_name)
        CL.append(cl_i)
        CD.append(cd_i)
        print(i,"-------->",cl_i,cd_i)
    data = {'CL': CL,'CD': CD}
    CL_CD = pd.DataFrame(data)
    
    # Return to the original directory
    os.chdir(original_directory)
    CL_CD.to_excel(file_name)
    return CL_CD

# %%
if globals().get('__file__', '') == '':
    file_name = 'new_Cl_Cd.xlsx'
    num_samples = 15
    CL_CD = new_deformed_foil_data_from_Xfoil(alpha, Re, n_iter, num_samples, file_name)
# Out:
# 0 --------> 0.6373 0.00791
# 1 --------> 0.6274 0.00794
# 2 --------> 0.6348 0.00792
# 3 --------> 0.641 0.00789
# 4 --------> 0.6373 0.00796
# 5 --------> 0.6386 0.00791
# 6 --------> 0.635 0.00792
# 7 --------> 0.6315 0.00789
# 8 --------> 0.6271 0.00797
# 9 --------> nan nan
# 10 --------> 0.6251 0.00798
# 11 --------> 0.6383 0.00789
# 12 --------> 0.6353 0.00795
# 13 --------> 0.6356 0.00791
# 14 --------> 0.6318 0.00793

# %%
new_df = pd.merge(new_sample_param, CL_CD, left_index=True, right_index=True)
new_df = new_df.dropna()
new_df
# Out:
#           x1        x2        x3        x4        x5        x6        x7  \
# 0   0.012000  0.011585 -0.006974 -0.011997  0.006540 -0.011989  0.011206
# 1   0.012000  0.007768 -0.002273 -0.012000  0.011855 -0.011839  0.006805
# 2   0.011626  0.011420 -0.006901 -0.011876  0.007370 -0.011933  0.009516
# 3   0.011900  0.012200 -0.006400 -0.012900  0.006100 -0.011300  0.011600
# 4   0.012900  0.010800 -0.007100 -0.011000  0.007400 -0.012100  0.010200
# 5   0.012200  0.011700 -0.006500 -0.012100  0.006800 -0.012700  0.012100
# 6   0.011000  0.011600 -0.007900 -0.011800  0.005800 -0.011500  0.010800
# 7   0.011900  0.008400 -0.001700 -0.012900  0.011500 -0.011200  0.007200
# 8   0.012900  0.007000 -0.002400 -0.011000  0.012700 -0.011900  0.005800
# 10  0.011000  0.007700 -0.003200 -0.011800  0.011100 -0.011400  0.006400
# 11  0.011500  0.012000 -0.006300 -0.012800  0.007000 -0.011300  0.009900
# 12  0.012500  0.010700 -0.007000 -0.010900  0.008300 -0.012000  0.008600
# 13  0.011800  0.011500 -0.006400 -0.012000  0.007600 -0.012700  0.010400
# 14  0.010700  0.011400 -0.007900 -0.011700  0.006600 -0.011500  0.009100
#
#           x8      CL       CD
# 0   0.011068  0.6373  0.00791
# 1   0.009451  0.6274  0.00794
# 2   0.011580  0.6348  0.00792
# 3   0.011300  0.6410  0.00789
# 4   0.010800  0.6373  0.00796
# 5   0.010500  0.6386  0.00791
# 6   0.012000  0.6350  0.00792
# 7   0.009700  0.6315  0.00789
# 8   0.009100  0.6271  0.00797
# 10  0.010400  0.6251  0.00798
# 11  0.011800  0.6383  0.00789
# 12  0.011300  0.6353  0.00795
# 13  0.011000  0.6356  0.00791
# 14  0.012500  0.6318  0.00793

# %%
new_dataset = pd.read_excel('new_dataset.xlsx')
new_dataset.drop(columns=['Unnamed: 0'], inplace=True)
new_dataset
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# 0    0.008400  0.010400 -0.003300 -0.003300 -0.008600  0.001500 -0.001900
# 1   -0.004500 -0.003500  0.005700  0.006200  0.010600 -0.006000  0.010100
# 2   -0.009300  0.003800 -0.008300 -0.011300  0.003000 -0.002800 -0.009300
# 3    0.001900 -0.009300  0.006700  0.002500 -0.001200  0.007700  0.002600
# 4    0.004500  0.001700  0.002600  0.005000 -0.003900  0.003400 -0.008700
# ..        ...       ...       ...       ...       ...       ...       ...
# 156 -0.000500  0.012100  0.012500  0.011800  0.012200  0.006700  0.009000
# 157 -0.001700  0.012000  0.011000  0.012200  0.011300  0.007900  0.007700
# 158  0.012000  0.011585 -0.006974 -0.011997  0.006540 -0.011989  0.011206
# 159  0.012000  0.007768 -0.002273 -0.012000  0.011855 -0.011839  0.006805
# 160  0.011626  0.011420 -0.006901 -0.011876  0.007370 -0.011933  0.009516
#
#            x8      CL       CD
# 0   -0.002700  0.5294  0.00733
# 1    0.003700  0.6747  0.00947
# 2    0.008500  0.4693  0.00959
# 3   -0.009200  0.5034  0.00928
# 4    0.010500  0.6249  0.00916
# ..        ...     ...      ...
# 156  0.004500  0.8246  0.00967
# 157  0.006000  0.8119  0.00981
# 158  0.011068  0.6373  0.00791
# 159  0.009451  0.6274  0.00794
# 160  0.011580  0.6348  0.00792
#
# [161 rows x 10 columns]

# %%
df_concatenated_dataset = pd.concat([new_dataset, new_df])
df_concatenated_dataset
# Out:
#         x1      x2      x3      x4      x5      x6      x7      x8      CL  \
# 0   0.0084  0.0104 -0.0033 -0.0033 -0.0086  0.0015 -0.0019 -0.0027  0.5294
# 1  -0.0045 -0.0035  0.0057  0.0062  0.0106 -0.0060  0.0101  0.0037  0.6747
# 2  -0.0093  0.0038 -0.0083 -0.0113  0.0030 -0.0028 -0.0093  0.0085  0.4693
# 3   0.0019 -0.0093  0.0067  0.0025 -0.0012  0.0077  0.0026 -0.0092  0.5034
# 4   0.0045  0.0017  0.0026  0.0050 -0.0039  0.0034 -0.0087  0.0105  0.6249
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 10  0.0110  0.0077 -0.0032 -0.0118  0.0111 -0.0114  0.0064  0.0104  0.6251
# 11  0.0115  0.0120 -0.0063 -0.0128  0.0070 -0.0113  0.0099  0.0118  0.6383
# 12  0.0125  0.0107 -0.0070 -0.0109  0.0083 -0.0120  0.0086  0.0113  0.6353
# 13  0.0118  0.0115 -0.0064 -0.0120  0.0076 -0.0127  0.0104  0.0110  0.6356
# 14  0.0107  0.0114 -0.0079 -0.0117  0.0066 -0.0115  0.0091  0.0125  0.6318
#
#          CD
# 0   0.00733
# 1   0.00947
# 2   0.00959
# 3   0.00928
# 4   0.00916
# ..      ...
# 10  0.00798
# 11  0.00789
# 12  0.00795
# 13  0.00791
# 14  0.00793
#
# [175 rows x 10 columns]

# %%
# df_concatenated_dataset.to_excel('new_dataset.xlsx')
